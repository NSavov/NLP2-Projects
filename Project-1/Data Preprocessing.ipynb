# %%
import numpy as np
from scipy.sparse import dok_matrix
import itertools
import time



directory_to_preprocess = "training" #"training" training" "validation"

if (directory_to_preprocess == "training"):
    english_file = directory_to_preprocess + "/hansards.36.2.e"
    french_file  = directory_to_preprocess + "/hansards.36.2.f"
    print("Preprocessing training set")
    
elif (directory_to_preprocess == "validation"):
    english_file = directory_to_preprocess + "/dev.e"
    french_file  = directory_to_preprocess + "/dev.f"
    print("Preprocessing validation set")
    
else:
    print("ERROR: pick either \"training\" or \"validation\"")
# Out:
# Preprocessing training set

# %%
import cPickle
import itertools

with open(english_file) as f:
    sentences_english = f.read().splitlines()
with open(french_file) as f:
    sentences_french = f.read().splitlines()
    

paired = []
for i, sentence_english in enumerate(sentences_english):
    paired.append([("null " + sentence_english.decode('utf-8')).split(" ")[0:-1], sentences_french[i].decode('utf-8').split(" ")[0:-1]])
#     ##TODO: CHECK IF DECODE WORKS PROPERLY


cPickle.dump(paired, open(directory_to_preprocess + "_pairs", 'wb'))

# %%
import time
import numpy as np

translation = {}
start = time.time()
for i,pair in enumerate(paired):
    for enWord in pair[0]:
        if enWord not in translation:
            translation[enWord] = {}
        for frWord in pair[1]:
            translation[enWord][frWord] = 0
end = time.time()
print end-start
            
            
#cPickle.dump(translation, open(directory_to_preprocess + "_empty_dictionary", 'wb'))
# Out:
# 38.1209998131

# %%
print(len(translation.keys()))
# Out:
# 36635

# %%
print translation.keys()
# Out:
# [u'1,800', u'Poetry', u'woods', u'hanging', u'trawling', u'localized', u'regularize', u'canes', u'originality', u'refunding', u'Western', u'alphabetic', u'Euro', u'Valli', u'wracked', u'stipulate', u'appropriation', u'Lajoie', u'strictest', u'bringing', u'ENVIRONMENT', u'wooded', u'wooden', u'viable', u'stereotypical', u'Transitions', u'insular', u'complainers', u'0055', u'270', u'271', u'272', u'273', u'274', u'275', u'276', u'sustaining', u'278', u'279', u'scraped', u'errors', u'deferred', u'cooking', u'recyclage', u'opportunists', u'Hamilton', u'designing', u'replaced', u'databank', u'succumb', u'shocks', u'Transat', u'Logging', u'mailings', u'affiliates', u'china', u'affiliated', u'confronts', u'chink', u'Mauritius', u'kids', u'climbed', u'controversy', u'Swayze', u'rebel', u'millimetres', u'golden', u'topography', u'projection', u'Harvey', u'lengthen', u'spacewalks', u'stern', u'ARTS', u'catchy', u'insecurity', u'1.26', u'MEMBER', u'Vernon', u'153.1', u'music', u'therefore', u'distortions', u'spaying', u'Diabetes', u'populations', u'LOUIS', u'UNITA', u'faceted', u'UNITY', u'31.1', u'5.15', u'Lessard', u'blustering', u'morally', u'locked', u'CHEMICAL', u'Colombia', u'Laviolette', u'Successor', u'Shabbits', u'phane', u'Le', u'Watrous', u'wand', u'La', u'unjust', u'Darling', u